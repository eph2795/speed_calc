# %%
import pandas as pd

# %%
target_path = 'soil_results/evaluation.xls'

# %%
df = pd.read_excel(target_path, header=0).set_index("'mod_no'")

# %%
df
# Out:
#                              'area'               'peri '  \
# 'mod_no'
# 'throat10097'  '375.08636578449915'  '147.56156565426096'
# 'throat1019'   '2698.0501033057812'  '445.37780554614017'
# 'throat2093'   '3102.0883264462773'  '477.58007112870473'
# 'throat2153'   '2786.4257369614484'  '462.08764604515994'
# 'throat2217'   '2106.4779999999973'  '406.52555152919234'
# 'throat2287'   '126.08730468749985'   '67.91950166067015'
# 'throat2291'      '97.095306122449'  '47.951533544885066'
# 'throat2293'   '154.07618141338682'   '65.93557504401348'
# 'throat2295'   '102.02692557422282'    '57.9164181127372'
# 'throat2297'   '145.19691230486666'   '79.87704072990888'
# 'throat2299'    '200.0242043426529'  '101.72340064727373'
# 'throat2343'   '148.10519249250947'    '69.9176463596534'
# 'throat2443'   '1628.6438605619119'   '280.1874180478458'
# 'throat2521'    '751.5936889648426'  '151.72414354868522'
# 'throat2531'   '1198.0474773242606'  '195.50759173991372'
# ...

# %%
import imageio

# %%
import matplotlib.pyplot as plt

# %%
img = imageio.imread('soil_results/throat4379.bmp')

# %%
img.shape[0] * img.shape[1]
# Out:
# 1435

# %%
(img[:, :, 0] == img[:, :, 3]).sum()
# Out:
# 893

# %%
plt.imshow(img[:, :, 3])
